# %%
import os
import shutil
import numpy as np

# %%
# Define the split percentages
train_split = 0.7
val_split = 0.15
test_split = 0.15

# %%
# Define the paths
source_folder = 'ChiSig'
train_folder = 'train'
val_folder = 'validation'
test_folder = 'test'

# %%
# Create folders for the splits
for folder in [train_folder, val_folder, test_folder]:
    os.makedirs(folder, exist_ok=True)
    os.makedirs(os.path.join(folder, 'positive'), exist_ok=True)
    os.makedirs(os.path.join(folder, 'negative'), exist_ok=True)

# %%
# Identify professional forgeries and corresponding originals
all_files = os.listdir(source_folder)

# %%
print(all_files)
# Out:
# ['叶良工-23-5.jpg', '叶高扬-91-1.jpg', '范阳曦-12-2.jpg', '罗语晨-62-2.jpg', '孔瑰玮-152-1.jpg', '王芳媛-6-1.jpg', '陆秋芳-62-3.jpg', '武厦洁-38-2.jpg', '尹秉文-35-3.jpg', '李成弘-108-4.jpg', '韩乐圣-40-1.jpg', '毛新洁-20-1.jpg', '于宋-147-1.jpg', '余冰凡-46-2.jpg', '郝冷亦-147-2.jpg', '邓承载-52-1.jpg', '江宏义-21-1.jpg', '韩乐圣-39-1.jpg', '史煊-18-1.jpg', '江夏萱-57-1.jpg', '龙康时-18-3.jpg', '毛昊怡-23-2.jpg', '沈凯乐-16-1.jpg', '吕啸-64-2.jpg', '张昊焱-54-1.jpg', '蔡洲-13-2.jpg', '江伟-143-4.jpg', '苏睿慈-4-2.jpg', '宋俊达-69-1.jpg', '姜子轩-108-2.jpg', '苏孤兰-47-4.jpg', '周乐欣-147-3.jpg', '萧痴旋-115-5.jpg', '许旭尧-62-2.jpg', '何弘和-45-5.jpg', '江秋华-91-1.jpg', '赵雅宁-6-4.jpg', '郭鸿运-92-1.jpg', '郑思淼-91-3.jpg', '邱意远-58-4.jpg', '萧综-65-1.jpg', '文文姝-92-2.jpg', '徐海桃-67-4.jpg', '薛高邈-49-1.jpg', '郭谊-41-4.jpg', '陆秋芳-62-5.jpg', '孟镰-32-2.jpg', '崔竹筱-197-4.jpg', '李菲-38-3.jpg', '蒋慕诗-83-1.jpg', '白光启-60-3.jpg', '许蔡琳-67-5.jpg', '宋文曜-19-5.jpg', '沈问-52-2.jpg', '刘莓-98-5.jpg', '苏渝-112-4.jpg', '熊谷玉-65-3.jpg', '余娴-51-1.jpg', '宋英才-12-1.jpg', '熊文虹-14-4.jpg', '江伟-60-3.jpg', '张星火-4-2.jpg', '康思源-92-1.jpg', '郭鸿运-107-2.jpg', '郭英勋-107-5.jpg', '崔敏达-9-1.jpg', '萧含文-7-2.jpg', '金飞鸿-115-4.jpg', '袁高韵-96-1.jpg', '龚弘伟-94-5.jpg', '孟宇文-15-5.jpg', '黄骞-67-4.jpg', '曾玉宸-22-2.jpg', '董正平-90-1.jpg', '叶柳瑾-96-5.jpg', '毛昊怡-197-3.jpg', '夏风-3-2.jpg', '杜清-26-2.jpg', '高荣-60-5.jpg', '段新霁-13-3.jpg', '熊文虹-15-5.jpg', '徐欣嘉-169-5.jpg', '萧含文-107-3.jpg', '赵宵雨-169-3.jpg', '赖雨蓉-12-2.jpg', '何安福-54-5.jpg', '刘嘉许-6-4.jpg', '文振国-59-5.jpg', '蔡洲-95-3.jpg', '姜暖瞳-38-3.jpg', '孙琳-46-5.jpg', '毛荭-130-2.jpg', '于宋-47-2.jpg', '毛荭-5-2.jpg', '江宏义-8-4.jpg', '胡蓓蕾-103-5.jpg', '尹秉文-49-4.jpg', '侯念-6-1.jpg', '邓文翰-33-5.jpg', '许玄穆-199-4.jpg', '吕钧-124-3.jpg', '钱璇-49-1.jpg', '石嫱-29-4.jpg', '陆会-22-1.jpg', '蒋玲然-30-2.jpg', '徐水格-169-1.jpg', '史勤-20-1.jpg', '任澉-98-4.jpg', '赖啸-96-3.jpg', '刘嘉许-98-5.jpg', '钟安邦-39-3.jpg', '何荌荌-49-4.jpg', '赖铎-66-2.jpg', '周函-91-1.jpg', '史意远-99-3.jpg', '何嘉懿-35-4.jpg', '孙正妍-48-1.jpg', '白光启-61-4.jpg', '顾星纬-63-1.jpg', '周娥-90-3.jpg', '袁飞虎-21-3.jpg', '何荌荌-49-3.jpg', '史意远-55-2.jpg', '何荌荌-58-3.jpg', '宋以蓝-17-3.jpg', '田薇歌-29-4.jpg', '贾天工-37-2.jpg', '任女-58-1.jpg', '袁越-29-5.jpg', '吕钧-54-5.jpg', '曾锐立-99-4.jpg', '江宏义-21-2.jpg', '任燕婉-2-2.jpg', '余冰凡-147-5.jpg', '毛诺瑶-107-3.jpg', '赖雨蓉-112-1.jpg', '余凯乐-133-2.jpg', '冯书蕾-167-1.jpg', '周慕灵-19-2.jpg', '赖芊芊-11-3.jpg', '常雪萍-68-1.jpg', '毛诺瑶-47-1.jpg', '曹乐成-41-4.jpg', '郑明哲-6-5.jpg', '任蔡琳-115-5.jpg', '蒋玲然-19-5.jpg', '陆浩思-44-1.jpg', '尹勇锐-1-4.jpg', '杜博涛-60-3.jpg', '毛诺瑶-28-3.jpg', '王芳媛-52-3.jpg', '秦凯歌-49-3.jpg', '崔敏达-33-1.jpg', '钟燕晓-42-3.jpg', '罗天罡-55-4.jpg', '秦凯歌-49-2.jpg', '邓承载-21-5.jpg', '李俊人-9-5.jpg', '范阳曦-51-3.jpg', '毛诺瑶-47-5.jpg', '郑明哲-26-2.jpg', '万恨荷-54-2.jpg', '陆浩思-44-5.jpg', '江成天-95-2.jpg', '阎琮-35-1.jpg', '曹乐成-133-1.jpg', '王宇达-2-3.jpg', '顾星纬-63-5.jpg', '余寒香-37-1.jpg', '薛妍-125-4.jpg', '白嘉荣-112-1.jpg', '常雪萍-97-2.jpg', '萧璧-36-4.jpg', '徐欣嘉-70-1.jpg', '张涵润-124-3.jpg', '秦开琼-12-5.jpg', '龙华奥-143-4.jpg', '康睿哲-136-3.jpg', '丁景澄-9-2.jpg', '尹天罡-21-2.jpg', '杨旭-89-3.jpg', '杜景山-9-4.jpg', '宋文曜-27-5.jpg', '郭谊-41-1.jpg', '毛含秀-120-4.jpg', '夏天佑-40-2.jpg', '沈凯乐-31-2.jpg', '万恨荷-14-1.jpg', '康勘-128-1.jpg', '史意远-6-4.jpg', '史苹-128-4.jpg', '康思源-92-4.jpg', '曹壮-51-2.jpg', '马雨信-103-3.jpg', '梁梦寒-112-4.jpg', '薛阳曜-44-2.jpg', '余弘新-38-4.jpg', '夏风-3-3.jpg', '李俊人-152-5.jpg', '段阳炎-97-4.jpg', '黎琳瑜-67-3.jpg', '杜飞鹏-18-2.jpg', '吴濮-69-5.jpg', '蒋思雅-36-3.jpg', '陈莉-71-4.jpg', '周娆-27-2.jpg', '金飞鸿-95-1.jpg', '龚蓝瑟-26-3.jpg', '徐水格-35-5.jpg', '韩超-13-1.jpg', '侯兴安-83-1.jpg', '钟燕晓-39-3.jpg', '孟茗-22-3.jpg', '曹壮-93-1.jpg', '田霞绮-130-4.jpg', '薛妍-125-3.jpg', '徐欣嘉-96-5.jpg', '田翰音-30-2.jpg', '贾妙竹-90-1.jpg', '黄骞-10-4.jpg', '哥舒莹琇-46-2.jpg', '汤代珊-25-4.jpg', '孔典雅-133-4.jpg', '周德海-52-2.jpg', '曾锐立-28-3.jpg', '宋俊达-152-4.jpg', '武松雪-46-5.jpg', '戴乐志-60-4.jpg', '卢文柏-42-1.jpg', '吴斯年-67-3.jpg', '丁瀚漠-30-4.jpg', '冯书蕾-67-5.jpg', '于珺琦-3-2.jpg', '孟鹏鹍-70-3.jpg', '曹飞昂-37-1.jpg', '白梓颖-167-1.jpg', '周函-91-2.jpg', '武厦洁-23-4.jpg', '何荌荌-49-1.jpg', '汤代珊-150-4.jpg', '苏渝-12-2.jpg', '孔尤文-68-1.jpg', '宋英才-12-5.jpg', '胡良骏-96-3.jpg', '谢嘉澍-29-5.jpg', '孟昭-13-1.jpg', '梁梦-55-5.jpg', '汤芳洲-62-4.jpg', '张英卓-120-3.jpg', '金飞鸿-47-4.jpg', '江成双-1-2.jpg', '何喆-7-1.jpg', ' ...

# %%
originals = set()
professional_forgeries = set()

# %%
for file in all_files:
    parts = file.split('-')
    if len(parts) < 3:
        continue

    number_a = int(parts[1])
    if number_a > 100:
        professional_forgeries.add(number_a)
        originals.add(number_a - 100)

# %%
# Function to determine label
def get_label(filename):
    number_a = int(filename.split('-')[1])

    # Original signature
    if number_a in originals:
        return 'positive'
    # Professional forgery
    elif number_a in professional_forgeries:
        return 'negative'
    # Random forgery
    else:
        return 'negative'

# %%
# Shuffle files
seed = 42
np.random.seed(seed)
np.random.shuffle(all_files)

# %%
# Split the files
total_files = len(all_files)
train_count = int(total_files * train_split)
val_count = int(total_files * val_split)

# %%
train_files = all_files[:train_count]
val_files = all_files[train_count:train_count + val_count]
test_files = all_files[train_count + val_count:]

# %%
def copy_files(files, target_folder):
    for file in files:
        label = get_label(file)
        if label:
            shutil.copy(os.path.join(source_folder, file), os.path.join(target_folder, label))

# %%
# Copy files to their respective sets
copy_files(train_files, train_folder)
copy_files(val_files, val_folder)
copy_files(test_files, test_folder)

print("Data splitting completed.")
# Out:
# Data splitting completed.
